# %%
import numpy as np
import pandas as pd
import statistics

# %%
import pandas as pd
import numpy as np


data = pd.DataFrame()
data['Tür'] = ['TekirKedi'] * 100 + ['SarmanKedi'] * 100 + ['BritishKedi'] * 100
data['Kilo'] = np.append(np.random.normal(10, 4, 150), np.random.normal(25, 5,150))
data['Boy'] = np.append(np.random.normal(60, 25, 150), np.random.normal(90, 15, 150))
data['Yaş'] = np.append(np.random.normal(5, 2, 150), np.random.normal(10, 5, 150))

# %%
data
# Out:
#              Tür       Kilo         Boy        Yaş
# 0      TekirKedi  12.551335   65.022064   5.473238
# 1      TekirKedi   5.471847  100.369292   4.271568
# 2      TekirKedi   7.447934   43.218470   5.496174
# 3      TekirKedi  12.430510   62.795664   5.467996
# 4      TekirKedi  10.634257   47.269332   7.781257
# ..           ...        ...         ...        ...
# 295  BritishKedi  28.876068   70.210648   9.810535
# 296  BritishKedi  31.884277   98.644800   6.679617
# 297  BritishKedi  26.246047  106.214682   9.361158
# 298  BritishKedi  23.574538   80.913165  13.322792
# 299  BritishKedi  22.749930   93.782948  11.561478
#
# [300 rows x 4 columns]

# %%
data.Boy.mean()
# Out:
# 76.17858488817542

# %%
data.Yaş.std()
# Out:
# 4.359416113875378

# %%
sum(data['Kilo']) / len(data['Kilo'])

np.std(data['Yaş'], ddof=1)
# Out:
# 4.359416113875378

# %%
"Soru 2"
# Out:
# 'Soru 2'

# %%
b=0.40
db = 0.02

# %%
print("Seçilen hatalı bilgisayrın b den olma ihtimali:" ,b*db)
# Out:
# Seçilen hatalı bilgisayrın b den olma ihtimali: 0.008

# %%
"Soru3"
# Out:
# 'Soru3'

# %%
dağılım = np.random.normal(20,10,5) 
dağılım
# Out:
# array([22.26597923, 43.25593596, 38.06022587, 32.19984663, 25.36495527])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
from scipy.stats import norm
mu = 0 
sigma = 1
n = 10000

plt.hist(dağılım)
plt.show()

# %%
from scipy import stats
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4), dpi = 200)
nsample = 100
res = stats.probplot(dağılım, plot=plt)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.DataFrame()
df = pd.read_csv("GOOG.csv" )
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2015-01-02   527.561584   529.815369   522.665039   523.373108
# 1    2015-01-05   521.827332   522.894409   511.655243   512.463013
# 2    2015-01-06   513.589966   514.761719   499.678131   500.585632
# 3    2015-01-07   505.611847   505.855164   498.281952   499.727997
# 4    2015-01-08   496.626526   502.101471   489.655640   501.303680
# ..          ...          ...          ...          ...          ...
# 750  2017-12-22  1061.109985  1064.199951  1059.439941  1060.119995
# 751  2017-12-26  1058.069946  1060.119995  1050.199951  1056.739990
# 752  2017-12-27  1057.390015  1058.369995  1048.050049  1049.369995
# 753  2017-12-28  1051.599976  1054.750000  1044.770020  1048.140015
# 754  2017-12-29  1046.719971  1049.699951  1044.900024  1046.400024
#
#        Adj Close   Volume
# 0     523.373108  1447563
# 1     512.463013  2059840
# 2     500.585632  2899940
# 3     499.727997  2065054
# ...

# %%
pilk=df.Open
pson=df.Close
pislem=(pilk-pson)/(pson)
pislem
# Out:
# 0      0.008003
# 1      0.018273
# 2      0.025978
# 3      0.011774
# 4     -0.009330
#          ...
# 750    0.000934
# 751    0.001259
# 752    0.007643
# 753    0.003301
# 754    0.000306
# Length: 755, dtype: float64

# %%
from scipy import stats
import matplotlib.pyplot as plt
plt.figure(figsize=(20,5), dpi =500)
nsample = 50
res = stats.probplot(pislem, plot=plt)
plt.title("Q-Q Çizgesi",)
plt.xlabel("ZAMAN", )
plt.ylabel("FARK", )
plt.show()

# %%
import random

# %%
random.randint(1,2)
# Out:
# 2

# %%
deneme=int(input("Deneme Yapılmasını istediginiz sayıyı giriniz"))
i=0
yazi= 0 
tura= 0

while True:
    q = random.randint(1,2)
    if(i==deneme):        
        print("yazi gelme ihtimali " + str(yazi/deneme),"yazi gelme ihtimali " + str(tura/deneme))
        break
    elif(q==1):
        yazi += 1
        i +=1
    else:
        tura +=1
        i +=1
# Out:
# Deneme Yapılmasını istediginiz sayıyı giriniz 200
# yazi gelme ihtimali 0.51 yazi gelme ihtimali 0.49

# %%
deneme=int(input("Deneme Yapılmasını istediginiz sayıyı giriniz"))
i=0
yazi= 0 
tura= 0

while True:
    q = random.randint(1,4)
    if(i==deneme):        
        print("yazi gelme ihtimali " + str(yazi/deneme),"yazi gelme ihtimali " + str(tura/deneme))
        break
    elif(q==1):
        yazi += 1
        i +=1
    else:
        tura +=1
        i +=1
# Out:
# Deneme Yapılmasını istediginiz sayıyı giriniz 100
# yazi gelme ihtimali 0.26 yazi gelme ihtimali 0.74

# %%
"Yukarıda yapılan işlemler sonucu örneklem olarak 1000 gibi bir deneme alınmış olsa bile Hileli olabilecek zarın anlaşıldığı ortadır"
# Out:
# 'Yukarıda yapılan işlemler sonucu örneklem olarak 1000 gibi bir deneme alınmış olsa bile Hileli olabilecek zarın anlaşıldığı ortadır'
